# %%
import numpy as np 
import os 
import torch
import open3d as o3d
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
from time import time
import numpy as np 
import torch.nn as nn
import torch.nn.functional as F

# %%
path = "/media/parvez/One_Touch/ScanNet/scans/scene0000_00/scene0000_00_vh_clean_2.ply"

# %%
pcd = o3d.io.read_point_cloud(path)

# %%
#o3d.visualization.draw_geometries([pcd],
#                                 )

# %%
points = np.asarray(pcd.points)
colors = np.asarray(pcd.colors)

# %%
print(points.shape)
# Out:
# (81369, 3)

# %%
def timeit(tag, t):
    print("{}: {}s".format(tag, time() - t))
    return time()

def pc_normalize(pc):
    l = pc.shape[0]
    centroid = np.mean(pc, axis=0)
    pc = pc - centroid
    m = np.max(np.sqrt(np.sum(pc**2, axis=1)))
    pc = pc / m
    return pc

def square_distance(src, dst):
    """
    Calculate Euclid distance between each two points.

    src^T * dst = xn * xm + yn * ym + zn * zm；
    sum(src^2, dim=-1) = xn*xn + yn*yn + zn*zn;
    sum(dst^2, dim=-1) = xm*xm + ym*ym + zm*zm;
    dist = (xn - xm)^2 + (yn - ym)^2 + (zn - zm)^2
         = sum(src**2,dim=-1)+sum(dst**2,dim=-1)-2*src^T*dst

    Input:
        src: source points, [B, N, C]
        dst: target points, [B, M, C]
    Output:
        dist: per-point square distance, [B, N, M]
    """
    B, N, _ = src.shape
    _, M, _ = dst.shape
    dist = -2 * torch.matmul(src, dst.permute(0, 2, 1))
    dist += torch.sum(src ** 2, -1).view(B, N, 1)
    dist += torch.sum(dst ** 2, -1).view(B, 1, M)
    return dist



def index_points(points, idx):
    """

    Input:
        points: input points data, [B, N, C]
        idx: sample index data, [B, S]
    Return:
        new_points:, indexed points data, [B, S, C]
    """
    device = points.device
    B = points.shape[0]
    view_shape = list(idx.shape)
    view_shape[1:] = [1] * (len(view_shape) - 1)
    repeat_shape = list(idx.shape)
    repeat_shape[0] = 1 
    idx = idx.to(torch.long)
    batch_indices = torch.arange(B, dtype=torch.long).to(device).view(view_shape).repeat(repeat_shape)
    new_points = points[batch_indices, idx, :]

    #print("batch shape=", batch_indices.shape, "idx shape=", idx.shape, "points = ", points.shape, "new points=", new_points.shape)
    return new_points

 

def farthest_point_sample(xyz, npoint):
    """
    Input:
        xyz: pointcloud data, [B, N, 3]
        npoint: number of samples
    Return:
        centroids: sampled pointcloud index, [B, point]
    """

    
    device = xyz.device
    B, N, C = xyz.shape
    centroids = torch.zeros(B, npoint, dtype=torch.float64).to(device)
    distance = torch.ones(B, N, dtype=torch.float64).to(device) * 1e10
    farthest = torch.randint(0, N, (B,), dtype=torch.long).to(device)
    batch_indices = torch.arange(B, dtype=torch.long).to(device)
    for i in range(npoint):
        centroids[:, i] = farthest 
        #print(xyz[batch_indices, farthest, :].shape, "in fps")
        centroid = xyz[batch_indices, farthest, :].view(B, 1, 3)
        dist = torch.sum((xyz - centroid) ** 2, -1)
        mask = dist < distance 
        dist = dist.to(torch.float64)
        #print(dist, "dist")
        #print(distance, "distance")
        distance[mask] = dist[mask]
        farthest = torch.max(distance, -1)[1]
    return centroids


def query_ball_point(radius, nsample, xyz, new_xyz):
    """
    Input:
        radius: local region radius
        nsample: max sample number in local region
        xyz: all points, [B, N, 3]
        new_xyz: query points, [B, S, 3]
    Return:
        group_idx: grouped points index, [B, S, nsample]
    """
    device = xyz.device
    B, N, C = xyz.shape
    _, S, _ = new_xyz.shape
    group_idx = torch.arange(N, dtype=torch.long).to(device).view(1, 1, N).repeat([B, S, 1])
    sqrdists = square_distance(new_xyz, xyz)
    group_idx[sqrdists > radius ** 2] = N
    group_idx = group_idx.sort(dim=-1)[0][:, :, :nsample]
    group_first = group_idx[:, :, 0].view(B, S, 1).repeat([1, 1, nsample])
    mask = group_idx == N
    group_idx[mask] = group_first[mask]
    return group_idx

# %%
def sample_and_group(npoint, radius, nsample, xyz, points, returnfps=False):
    """
    Input:
        npoint:
        radius:
        nsample:
        xyz: input points position data, [B, N, 3]
        points: input points data, [B, N, D]
    Return:
        new_xyz: sampled points position data, [B, npoint, nsample, 3]
        new_points: sampled points data, [B, npoint, nsample, 3+D]
    """
    B, N, C = xyz.shape
    S = npoint
    fps_idx = farthest_point_sample(xyz, npoint) # [B, npoint, C]
    torch.cuda.empty_cache()
    new_xyz = index_points(xyz, fps_idx)
    torch.cuda.empty_cache()
    idx = query_ball_point(radius, nsample, xyz, new_xyz)   # idx can have outlier index like max size
    torch.cuda.empty_cache()
    grouped_xyz = index_points(xyz, idx) # [B, npoint, nsample, C]   # verify shape
    torch.cuda.empty_cache()
    grouped_xyz_norm = grouped_xyz - new_xyz.view(B, S, 1, C)
    torch.cuda.empty_cache()

    #print("in sample and group all")
    if points is not None:
        grouped_points = index_points(points, idx)
        new_points = torch.cat([grouped_xyz_norm, grouped_points], dim=-1) # [B, npoint, nsample, C+D]
    else:
        new_points = grouped_xyz_norm
    if returnfps:
        return new_xyz, new_points, grouped_xyz, fps_idx
    else:
        return new_xyz, new_points

# %%
class PointNetSetAbstraction(nn.Module):
    def __init__(self, npoint, radius, nsample, in_channel, mlp, group_all):
        super(PointNetSetAbstraction, self).__init__()
        self.npoint = npoint
        self.radius = radius
        self.nsample = nsample
        self.mlp_convs = nn.ModuleList()
        self.mlp_bns = nn.ModuleList()
        last_channel = in_channel
        for out_channel in mlp:
            self.mlp_convs.append(nn.Conv2d(last_channel, out_channel, 1))
            self.mlp_bns.append(nn.BatchNorm2d(out_channel))
            last_channel = out_channel
        self.group_all = group_all

    def forward(self, xyz, points):
        """
        Input:
            xyz: input points position data, [B, C, N]
            points: input points data, [B, D, N]
        Return:
            new_xyz: sampled points position data, [B, C, S]
            new_points_concat: sample points feature data, [B, D', S]
        """
        #print(xyz.shape, "XYZ")
        xyz = xyz.permute(0, 2, 1)
        if points is not None:
            points = points.permute(0, 2, 1)

        if self.group_all:
            new_xyz, new_points = sample_and_group_all(xyz, points)
        else:
            new_xyz, new_points = sample_and_group(self.npoint, self.radius, self.nsample, xyz, points)
        # new_xyz: sampled points position data, [B, npoint, C]
        # new_points: sampled points data, [B, npoint, nsample, C+D]
        #print("new_ponts before",  print("hello")new_points.shape)
        #print("hello")
        new_points = new_points.permute(0, 3, 2, 1).float() # [B, C+D, nsample,npoint]

        #print("hello Point abstraction")
        for i, conv in enumerate(self.mlp_convs):
            bn = self.mlp_bns[i]
            new_points =  F.relu(bn(conv(new_points)))
        #print(new_points.shape, "new points")
        new_points = torch.max(new_points, 2)[0]
        new_xyz = new_xyz.permute(0, 2, 1)
        return new_xyz, new_points

# %%
class get_model(nn.Module):
    def __init__(self, num_classes):
        super(get_model, self).__init__()
        self.sa1 = PointNetSetAbstraction(1024, 0.1, 32, 9+3, [32, 32, 64], False)
        self.sa2 = PointNetSetAbstraction(256, 0.2, 32, 64 + 3, [64, 64, 128], False)
        self.sa3 = PointNetSetAbstraction(64, 0.4, 32, 128 + 3, [128, 128, 256], False)
        self.sa4 = PointNetSetAbstraction(16, 0.8, 32, 256 + 3, [256, 256, 512], False)
        self.conv1 = nn.Conv1d(512, 128, 1)
        self.bn1 = nn.BatchNorm1d(128)
        self.drop1 = nn.Dropout(0.5)
        self.conv2 = nn.Conv1d(128, num_classes, 1)

    def forward(self, xyz):
        l0_points = xyz
        l0_xyz = xyz[:,:3,:]


        l1_xyz, l1_points = self.sa1(l0_xyz, l0_points) 
        print(l1_xyz.shape, l1_points.shape, "sa1")
        l2_xyz, l2_points = self.sa2(l1_xyz, l1_points)
        print(l2_xyz.shape, l2_points.shape, "sa2")
        l3_xyz, l3_points = self.sa3(l2_xyz, l2_points)
        print(l3_xyz.shape, l3_points.shape, "sa3")
        l4_xyz, l4_points = self.sa4(l3_xyz, l3_points)
        print(l4_xyz.shape, l4_points.shape, "sa4")



        x = self.drop1(F.relu(self.bn1(self.conv1(l4_points))))
        x = self.conv2(x)
        x = F.log_softmax(x, dim=1)
        x = x.permute(0, 2, 1)
        return x, l4_points

# %%
model = get_model(13)

# %%
model
# Out:
# get_model(
#   (sa1): PointNetSetAbstraction(
#     (mlp_convs): ModuleList(
#       (0): Conv2d(12, 32, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (mlp_bns): ModuleList(
#       (0-1): 2 x BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (sa2): PointNetSetAbstraction(
#     (mlp_convs): ModuleList(
#       (0): Conv2d(67, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (mlp_bns): ModuleList(
#       (0-1): 2 x BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (sa3): PointNetSetAbstraction(
#     (mlp_convs): ModuleList(
#       (0): Conv2d(131, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (mlp_bns): ModuleList(
#       (0-1): 2 x BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (sa4): PointNetSetAbstraction(
#     (mlp_convs): ModuleList(
#       (0): Conv2d(259, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       (2): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (mlp_bns): ModuleList(
#       (0-1): 2 x BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fp4): PointNetFeaturePropagation(
#     (mlp_convs): ModuleList(
#       (0): Conv1d(768, 256, kernel_size=(1,), stride=(1,))
#       (1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#     )
#     (mlp_bns): ModuleList(
#       (0-1): 2 x BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fp3): PointNetFeaturePropagation(
#     (mlp_convs): ModuleList(
#       (0): Conv1d(384, 256, kernel_size=(1,), stride=(1,))
#       (1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#     )
#     (mlp_bns): ModuleList(
#       (0-1): 2 x BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fp2): PointNetFeaturePropagation(
#     (mlp_convs): ModuleList(
#       (0): Conv1d(320, 256, kernel_size=(1,), stride=(1,))
#       (1): Conv1d(256, 128, kernel_size=(1,), stride=(1,))
#     )
#     (mlp_bns): ModuleList(
#       (0): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fp1): PointNetFeaturePropagation(
#     (mlp_convs): ModuleList(
#       (0-2): 3 x Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#     )
#     (mlp_bns): ModuleList(
#       (0-2): 3 x BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv1): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.5, inplace=False)
#   (conv2): Conv1d(128, 13, kernel_size=(1,), stride=(1,))
# )

# %%
xyz = torch.rand(6, 9, 2048)
x, l4_points = model(xyz)
# Out:
# torch.Size([6, 3, 1024]) torch.Size([6, 64, 1024]) sa1
# torch.Size([6, 3, 256]) torch.Size([6, 128, 256]) sa2
# torch.Size([6, 3, 64]) torch.Size([6, 256, 64]) sa3
# torch.Size([6, 3, 16]) torch.Size([6, 512, 16]) sa4
# torch.Size([6, 64, 16]) dists
# torch.Size([6, 256, 64]) dists
# torch.Size([6, 1024, 256]) dists
# torch.Size([6, 2048, 1024]) dists

# %%
x.shape
# Out:
# torch.Size([6, 2048, 13])

# %%
l4_points.shape
# Out:
# torch.Size([6, 512, 16])

# %%
points = torch.from_numpy(points).unsqueeze(dim=0).permute(0,2,1).to(torch.long)

# %%
# Out:
# tensor([[37., 37., 37.,  ...,  6.,  6.,  6.]], dtype=torch.float64) dist
# tensor([[1.0000e+10, 1.0000e+10, 1.0000e+10,  ..., 1.0000e+10, 1.0000e+10,
#          1.0000e+10]], dtype=torch.float64) distance
# tensor([[ 8.,  8.,  8.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[37., 37., 37.,  ...,  6.,  6.,  6.]], dtype=torch.float64) distance
# tensor([[21., 21., 21.,  ..., 52., 52., 52.]], dtype=torch.float64) dist
# tensor([[8., 8., 8.,  ..., 6., 6., 6.]], dtype=torch.float64) distance
# tensor([[45., 45., 45.,  ..., 20., 20., 20.]], dtype=torch.float64) dist
# tensor([[8., 8., 8.,  ..., 6., 6., 6.]], dtype=torch.float64) distance
# tensor([[ 5.,  5.,  5.,  ..., 30., 30., 30.]], dtype=torch.float64) dist
# tensor([[8., 8., 8.,  ..., 6., 6., 6.]], dtype=torch.float64) distance
# tensor([[45., 45., 45.,  ..., 20., 20., 20.]], dtype=torch.float64) dist
# tensor([[5., 5., 5.,  ..., 6., 6., 6.]], dtype=torch.float64) distance
# tensor([[13., 13., 13.,  ..., 24., 24., 24.]], dtype=torch.float64) dist
# tensor([[5., 5., 5.,  ..., 6., 6., 6.]], dtype=torch.float64) distance
# tensor([[53., 53., 53.,  ...,  8.,  8.,  8.]], dtype=torch.float64) dist
# tensor([[5., 5., 5.,  ..., 6., 6., 6.]], dtype=torch.float64) distance
# tensor([[72., 72., 72.,  ...,  5.,  5.,  5.]], dtype=torch.float64) dist
# tensor([[5., 5., 5.,  ..., 6., 6., 6.]], dtype=torch.float64) distance
# tensor([[ 5.,  5.,  5.,  ..., 50., 50., 50.]], dtype=torch.float64) dist
# tensor([[5., 5., 5.,  ..., 5., 5., 5.]], dtype=torch.float64) distance
# tensor([[25., 25., 25.,  ..., 36., 36., 36.]], dtype=torch.float64) dist
# tensor([[5., 5., 5.,  ..., 5., 5., 5.]], dtype=torch.float64) distance
# tensor([[27., 27., 27.,  ...,  6.,  6.,  6.]], dtype=torch.float64) dist
# tensor([[5., 5., 5.,  ..., 5., 5., 5.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[5., 5., 5.,  ..., 5., 5., 5.]], dtype=torch.float64) distance
# tensor([[10., 10., 10.,  ..., 49., 49., 49.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 5., 5., 5.]], dtype=torch.float64) distance
# tensor([[17., 17., 17.,  ..., 34., 34., 34.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 5., 5., 5.]], dtype=torch.float64) distance
# tensor([[20., 20., 20.,  ..., 17., 17., 17.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 5., 5., 5.]], dtype=torch.float64) distance
# tensor([[32., 32., 32.,  ..., 29., 29., 29.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 5., 5., 5.]], dtype=torch.float64) distance
# tensor([[58., 58., 58.,  ..., 13., 13., 13.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 5., 5., 5.]], dtype=torch.float64) distance
# tensor([[53., 53., 53.,  ...,  0.,  0.,  0.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 5., 5., 5.]], dtype=torch.float64) distance
# tensor([[ 5.,  5.,  5.,  ..., 44., 44., 44.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[29., 29., 29.,  ..., 32., 32., 32.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[44., 44., 44.,  ...,  5.,  5.,  5.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[52., 52., 52.,  ..., 21., 21., 21.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[57., 57., 57.,  ...,  4.,  4.,  4.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[65., 65., 65.,  ...,  6.,  6.,  6.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[16., 16., 16.,  ..., 13., 13., 13.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[54., 54., 54.,  ..., 11., 11., 11.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 2.,  2.,  2.,  ..., 51., 51., 51.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 6.,  6.,  6.,  ..., 41., 41., 41.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 6.,  6.,  6.,  ..., 37., 37., 37.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[11., 11., 11.,  ..., 46., 46., 46.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[21., 21., 21.,  ..., 42., 42., 42.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 5.,  5.,  5.,  ..., 30., 30., 30.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[13., 13., 13.,  ..., 38., 38., 38.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 9.,  9.,  9.,  ..., 30., 30., 30.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[19., 19., 19.,  ..., 26., 26., 26.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[19., 19., 19.,  ..., 26., 26., 26.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[33., 33., 33.,  ..., 26., 26., 26.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[21., 21., 21.,  ..., 14., 14., 14.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[29., 29., 29.,  ..., 18., 18., 18.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[29., 29., 29.,  ..., 32., 32., 32.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[35., 35., 35.,  ..., 14., 14., 14.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[29., 29., 29.,  ..., 18., 18., 18.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[29., 29., 29.,  ..., 12., 12., 12.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[27., 27., 27.,  ...,  6.,  6.,  6.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[37., 37., 37.,  ...,  6.,  6.,  6.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[41., 41., 41.,  ...,  6.,  6.,  6.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[35., 35., 35.,  ..., 14., 14., 14.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[54., 54., 54.,  ...,  5.,  5.,  5.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[49., 49., 49.,  ...,  4.,  4.,  4.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[51., 51., 51.,  ...,  2.,  2.,  2.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 1.,  1.,  1.,  ..., 50., 50., 50.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 4.,  4.,  4.,  ..., 49., 49., 49.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 1.,  1.,  1.,  ..., 54., 54., 54.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 5.,  5.,  5.,  ..., 50., 50., 50.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 5.,  5.,  5.,  ..., 54., 54., 54.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[14., 14., 14.,  ..., 45., 45., 45.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 5.,  5.,  5.,  ..., 44., 44., 44.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[11., 11., 11.,  ..., 46., 46., 46.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 1.,  1.,  1.,  ..., 54., 54., 54.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 2.,  2.,  2.,  ..., 41., 41., 41.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 2.,  2.,  2.,  ..., 51., 51., 51.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 3.,  3.,  3.,  ..., 38., 38., 38.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 5.,  5.,  5.,  ..., 54., 54., 54.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 1.,  1.,  1.,  ..., 40., 40., 40.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 2.,  2.,  2.,  ..., 41., 41., 41.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 6.,  6.,  6.,  ..., 41., 41., 41.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 4.,  4.,  4.,  ..., 57., 57., 57.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 9.,  9.,  9.,  ..., 40., 40., 40.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 3.,  3.,  3.,  ..., 38., 38., 38.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[14., 14., 14.,  ..., 45., 45., 45.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[20., 20., 20.,  ..., 45., 45., 45.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[17., 17., 17.,  ..., 56., 56., 56.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[24., 24., 24.,  ..., 41., 41., 41.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[18., 18., 18.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[13., 13., 13.,  ..., 38., 38., 38.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[14., 14., 14.,  ..., 35., 35., 35.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 8.,  8.,  8.,  ..., 33., 33., 33.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 4.,  4.,  4.,  ..., 29., 29., 29.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 8.,  8.,  8.,  ..., 33., 33., 33.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[14., 14., 14.,  ..., 35., 35., 35.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[12., 12., 12.,  ..., 29., 29., 29.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[26., 26., 26.,  ..., 33., 33., 33.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[18., 18., 18.,  ..., 29., 29., 29.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[13., 13., 13.,  ..., 24., 24., 24.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[10., 10., 10.,  ..., 21., 21., 21.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 9.,  9.,  9.,  ..., 20., 20., 20.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[10., 10., 10.,  ..., 21., 21., 21.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[18., 18., 18.,  ..., 29., 29., 29.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[22., 22., 22.,  ..., 25., 25., 25.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[25., 25., 25.,  ..., 22., 22., 22.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[32., 32., 32.,  ..., 29., 29., 29.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[36., 36., 36.,  ..., 25., 25., 25.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[17., 17., 17.,  ..., 14., 14., 14.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[17., 17., 17.,  ..., 14., 14., 14.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[20., 20., 20.,  ..., 17., 17., 17.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[25., 25., 25.,  ..., 22., 22., 22.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[26., 26., 26.,  ..., 19., 19., 19.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[33., 33., 33.,  ..., 26., 26., 26.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[26., 26., 26.,  ..., 33., 33., 33.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[36., 36., 36.,  ..., 25., 25., 25.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[26., 26., 26.,  ..., 19., 19., 19.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[34., 34., 34.,  ..., 17., 17., 17.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[38., 38., 38.,  ..., 13., 13., 13.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[29., 29., 29.,  ..., 12., 12., 12.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[26., 26., 26.,  ...,  9.,  9.,  9.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[25., 25., 25.,  ...,  8.,  8.,  8.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[26., 26., 26.,  ...,  9.,  9.,  9.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[18., 18., 18.,  ..., 11., 11., 11.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[30., 30., 30.,  ...,  9.,  9.,  9.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[34., 34., 34.,  ..., 17., 17., 17.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[41., 41., 41.,  ..., 24., 24., 24.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[42., 42., 42.,  ..., 21., 21., 21.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[38., 38., 38.,  ..., 13., 13., 13.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[45., 45., 45.,  ..., 14., 14., 14.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[46., 46., 46.,  ..., 11., 11., 11.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[49., 49., 49.,  ..., 10., 10., 10.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[40., 40., 40.,  ...,  9.,  9.,  9.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[41., 41., 41.,  ...,  6.,  6.,  6.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[30., 30., 30.,  ...,  9.,  9.,  9.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[33., 33., 33.,  ...,  8.,  8.,  8.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[38., 38., 38.,  ...,  3.,  3.,  3.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[41., 41., 41.,  ...,  2.,  2.,  2.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[36., 36., 36.,  ...,  5.,  5.,  5.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[40., 40., 40.,  ...,  9.,  9.,  9.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[38., 38., 38.,  ...,  3.,  3.,  3.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[44., 44., 44.,  ...,  5.,  5.,  5.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[45., 45., 45.,  ..., 14., 14., 14.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[46., 46., 46.,  ..., 11., 11., 11.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[49., 49., 49.,  ..., 10., 10., 10.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[53., 53., 53.,  ..., 18., 18., 18.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[56., 56., 56.,  ..., 17., 17., 17.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[53., 53., 53.,  ...,  8.,  8.,  8.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[59., 59., 59.,  ..., 10., 10., 10.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[50., 50., 50.,  ...,  5.,  5.,  5.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[50., 50., 50.,  ...,  1.,  1.,  1.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[51., 51., 51.,  ...,  2.,  2.,  2.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[54., 54., 54.,  ...,  1.,  1.,  1.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[50., 50., 50.,  ...,  5.,  5.,  5.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[54., 54., 54.,  ...,  1.,  1.,  1.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[54., 54., 54.,  ...,  5.,  5.,  5.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[68., 68., 68.,  ...,  9.,  9.,  9.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[69., 69., 69.,  ...,  6.,  6.,  6.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[66., 66., 66.,  ...,  3.,  3.,  3.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[69., 69., 69.,  ...,  2.,  2.,  2.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# ...
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# tensor([[ 0.,  0.,  0.,  ..., 53., 53., 53.]], dtype=torch.float64) dist
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64) distance
# in sample and group all
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[967], line 1
# ----> 1 sa1(points, None)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[961], line 43, in PointNetSetAbstraction.forward(self, xyz, points)
#      41 for i, conv in enumerate(self.mlp_convs):
#      42     bn = self.mlp_bns[i]
# ---> 43     new_points =  F.relu(bn(conv(new_points)))
#      44 #print(new_points.shape, "new points")
#      45 new_points = torch.max(new_points, 2)[0]
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# RuntimeError: Given groups=1, weight of size [32, 12, 1, 1], expected input[1, 3, 32, 1024] to have 12 channels, but got 3 channels instead

# %%
new_xyz, new_points = model(points, None)

# %%
new_xyz.shape
# Out:
# torch.Size([1, 3, 200])

# %%
new_points.shape
# Out:
# torch.Size([1, 64, 200])
